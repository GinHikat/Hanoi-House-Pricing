# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

import nltk

# %%
df = pd.read_csv('C:/Users/admin/Downloads/ML1 Mid Prj/ML1 Mid Prj/user_data.csv', index_col = 0)

# %%
df
# Out:
#               Age                    Review  Score
# Name
# PHAM DUY ANH   20            hahah so goood    5.0
# minh           30  so bad i can't live here    1.0
# dong           20       too good to be true    3.0
# vinh           20                    nice!!    4.0
